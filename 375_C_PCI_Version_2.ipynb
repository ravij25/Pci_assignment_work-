# %%
import pandas as pd

# %%
df= pd.read_excel(r"E:\AI\Mongodb\375_EC_1.xlsx")

# %%
df.head()
# Out:
#     EC No.  / Item No./ Institution Name /ID/ Course Unnamed: 1  Unnamed: 2  \
# 0                                                NaN        NaN         NaN
# 1  375EC/4\nAP-129/ 2022-2023\nP Rami Reddy Memor...        NaN         NaN
# 2  375EC/5\nAP-130/ 2022-2023\nVignan Pharmacy Co...        NaN         NaN
# 3   EC No.  / Item No./ Institution Name /ID/ Course        NaN         NaN
# 4                                                NaN        NaN         NaN
#
#   Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0        NaN         NaN         NaN         NaN         NaN         NaN
# 1        NaN         NaN         NaN         NaN         NaN         NaN
# 2        NaN         NaN         NaN         NaN         NaN         NaN
# 3        NaN         NaN         NaN         NaN         NaN         NaN
# 4        NaN         NaN         NaN         NaN         NaN         NaN
#
#                       Examining Authority / Hospital  \
# ...

# %%
#Dataframe name change
df['Examining Authority']=df['Examining Authority / Hospital']

# %%
df.head()
# Out:
#     EC No.  / Item No./ Institution Name /ID/ Course Unnamed: 1  Unnamed: 2  \
# 0                                                NaN        NaN         NaN
# 1  375EC/4\nAP-129/ 2022-2023\nP Rami Reddy Memor...        NaN         NaN
# 2  375EC/5\nAP-130/ 2022-2023\nVignan Pharmacy Co...        NaN         NaN
# 3   EC No.  / Item No./ Institution Name /ID/ Course        NaN         NaN
# 4                                                NaN        NaN         NaN
#
#   Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0        NaN         NaN         NaN         NaN         NaN         NaN
# 1        NaN         NaN         NaN         NaN         NaN         NaN
# 2        NaN         NaN         NaN         NaN         NaN         NaN
# 3        NaN         NaN         NaN         NaN         NaN         NaN
# 4        NaN         NaN         NaN         NaN         NaN         NaN
#
#                       Examining Authority / Hospital  \
# ...

# %%
df.dtypes
# Out:
# EC No.  / Item No./ Institution Name /ID/ Course     object
# Unnamed: 1                                           object
# Unnamed: 2                                          float64
# Unnamed: 3                                           object
# Unnamed: 4                                          float64
# Unnamed: 5                                          float64
# Unnamed: 6                                          float64
# Unnamed: 7                                          float64
# Unnamed: 8                                          float64
# Examining Authority / Hospital                       object
# Decisions of\n375 EC (26.8.2022)                     object
# Unnamed: 11                                          object
# Unnamed: 12                                          object
# Unnamed: 13                                          object
# Unnamed: 14                                          object
# Examining Authority                                  object
# ...

# %%
df['Institution_Name']=df['EC No.  / Item No./ Institution Name /ID/ Course']

# %%
df2=df[['Institution_Name', 'Examining Authority', 'Decisions of\n375 EC (26.8.2022)']]

# %%
df2.head()
# Out:
#                                     Institution_Name  \
# 0                                                NaN
# 1  375EC/4\nAP-129/ 2022-2023\nP Rami Reddy Memor...
# 2  375EC/5\nAP-130/ 2022-2023\nVignan Pharmacy Co...
# 3   EC No.  / Item No./ Institution Name /ID/ Course
# 4                                                NaN
#
#                                  Examining Authority  \
# 0                                                NaN
# 1  D.Pharm\nState Board of Technical Education an...
# 2  B.Pharm, Pharm.D and M.Pharm\nThe Registrar,\n...
# 3                     Examining Authority / Hospital
# 4                                                NaN
#
#                     Decisions of\n375 EC (26.8.2022)
# 0                                                NaN
# 1  D.Pharm\nGrant approval for 2022-2023 academic...
# 2  B.Pharm\nB.Pharm course is already approved up...
# 3                   Decisions of\n375 EC (26.8.2022)
# 4                                                NaN

# %%
# converting dataframe as string
df2=df2.applymap(str)
print(df2.dtypes)
# Out:
# Institution_Name                    object
# Examining Authority                 object
# Decisions of\n375 EC (26.8.2022)    object
# dtype: object

# %%
# find the string position 
df2.Institution_Name.str.find('PCI')
# Out:
# 0       -1
# 1      100
# 2       89
# 3       -1
# 4       -1
#       ...
# 260     -1
# 261     -1
# 262    119
# 263     -1
# 264     -1
# Name: Institution_Name, Length: 265, dtype: int64

# %%
df['PCI']=df.Institution_Name.str.split(' ')

# %%
df['PCI']
# Out:
# 0                                                    NaN
# 1      [375EC/4\nAP-129/, 2022-2023\nP, Rami, Reddy, ...
# 2      [375EC/5\nAP-130/, 2022-2023\nVignan, Pharmacy...
# 3      [EC, No., , /, Item, No./, Institution, Name, ...
# 4                                                    NaN
#                              ...
# 260                                                  NaN
# 261                                                  NaN
# 262    [375EC/69, &, 70\nKA-329, /, 2022-2023\nKARNAT...
# 263                                                  NaN
# 264                                               [p.36]
# Name: PCI, Length: 265, dtype: object

# %%
# conerting a new column from instute
df2['PCI'] = df2.Institution_Name.str.extract(r'\b(\w+)$', expand=True)
print(df2)
# Out:
#                                       Institution_Name  \
# 0                                                  nan
# 1    375EC/4\nAP-129/ 2022-2023\nP Rami Reddy Memor...
# 2    375EC/5\nAP-130/ 2022-2023\nVignan Pharmacy Co...
# 3     EC No.  / Item No./ Institution Name /ID/ Course
# 4                                                  nan
# ..                                                 ...
# 260                                                nan
# 261                                                nan
# 262  375EC/69 & 70\nKA-329 / 2022-2023\nKARNATAKA\n...
# 263                                                nan
# 264                                               p.36
#
#                                    Examining Authority  \
# 0                                                  nan
# 1    D.Pharm\nState Board of Technical Education an...
# 2    B.Pharm, Pharm.D and M.Pharm\nThe Registrar,\n...
# 3                       Examining Authority / Hospital
# ...

# %%
df2.head()
# Out:
#                                     Institution_Name  \
# 0                                                nan
# 1  375EC/4\nAP-129/ 2022-2023\nP Rami Reddy Memor...
# 2  375EC/5\nAP-130/ 2022-2023\nVignan Pharmacy Co...
# 3   EC No.  / Item No./ Institution Name /ID/ Course
# 4                                                nan
#
#                                  Examining Authority  \
# 0                                                nan
# 1  D.Pharm\nState Board of Technical Education an...
# 2  B.Pharm, Pharm.D and M.Pharm\nThe Registrar,\n...
# 3                     Examining Authority / Hospital
# 4                                                nan
#
#                     Decisions of\n375 EC (26.8.2022)     PCI
# 0                                                nan     nan
# 1  D.Pharm\nGrant approval for 2022-2023 academic...   Pharm
# 2  B.Pharm\nB.Pharm course is already approved up...   Pharm
# 3                   Decisions of\n375 EC (26.8.2022)  Course
# ...

# %%
df2.shape
# Out:
# (265, 4)

# %%
df2.tail(10)
# Out:
#                                       Institution_Name  \
# 255                                                nan
# 256                                                nan
# 257                                                nan
# 258  375EC/68\nMH-480 / 2022-2023\nShiva Trusts Raj...
# 259   EC No.  / Item No./ Institution Name /ID/ Course
# 260                                                nan
# 261                                                nan
# 262  375EC/69 & 70\nKA-329 / 2022-2023\nKARNATAKA\n...
# 263                                                nan
# 264                                               p.36
#
#                                    Examining Authority  \
# 255                                                nan
# 256  Technological\nUniversity, Lonere Vidyavihar, ...
# 257                                                nan
# 258  D.Pharm\nThe Secretary\nMaharashtra State Boar...
# 259                     Examining Authority / Hospital
# ...

# %%
df2 = df2.assign(PCI=df2['Institution_Name'].str.extract('(PCI.*)'))

# %%
df2.head()
# Out:
#                                     Institution_Name  \
# 0                                                nan
# 1  375EC/4\nAP-129/ 2022-2023\nP Rami Reddy Memor...
# 2  375EC/5\nAP-130/ 2022-2023\nVignan Pharmacy Co...
# 3   EC No.  / Item No./ Institution Name /ID/ Course
# 4                                                nan
#
#                                  Examining Authority  \
# 0                                                nan
# 1  D.Pharm\nState Board of Technical Education an...
# 2  B.Pharm, Pharm.D and M.Pharm\nThe Registrar,\n...
# 3                     Examining Authority / Hospital
# 4                                                nan
#
#                     Decisions of\n375 EC (26.8.2022)                  PCI  \
# 0                                                nan                  NaN
# 1  D.Pharm\nGrant approval for 2022-2023 academic...  PCI – 1519 PCI-1519
# 2  B.Pharm\nB.Pharm course is already approved up...           PCI – 2596
# ...

# %%
df2.shape
# Out:
# (265, 5)

# %%
PCI_Work2=df2[['PCI', 'Institution_Name', 'Examining Authority', 'Decisions of\n375 EC (26.8.2022)' ]]

# %%
PCI_Work2.head()
# Out:
#                    PCI                                   Institution_Name  \
# 0                  NaN                                                nan
# 1  PCI – 1519 PCI-1519  375EC/4\nAP-129/ 2022-2023\nP Rami Reddy Memor...
# 2           PCI – 2596  375EC/5\nAP-130/ 2022-2023\nVignan Pharmacy Co...
# 3                  NaN   EC No.  / Item No./ Institution Name /ID/ Course
# 4                  NaN                                                nan
#
#                                  Examining Authority  \
# 0                                                nan
# 1  D.Pharm\nState Board of Technical Education an...
# 2  B.Pharm, Pharm.D and M.Pharm\nThe Registrar,\n...
# 3                     Examining Authority / Hospital
# 4                                                nan
#
#                     Decisions of\n375 EC (26.8.2022)
# 0                                                nan
# 1  D.Pharm\nGrant approval for 2022-2023 academic...
# ...
