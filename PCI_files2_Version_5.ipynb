# %%
import pandas as pd

# %%
df= pd.read_excel(r"E:\AI\Mongodb\374EC.xlsx")

# %%
df= pd.read_excel(r"E:\AI\Mongodb\374EC.xlsx")

# %%
df.head()
# Out:
#      EC No. / Item No./ Institution Name /ID/ Course Unnamed: 1  Unnamed: 2  \
# 0  374EC/1\nAP-117/ 2022-2023\nAU College of Phar...        NaN         NaN
# 1  374EC/2\nAP-118/ 2022-2023\nGitam Institute of...        NaN         NaN
# 2    EC No. / Item No./ Institution Name /ID/ Course        NaN         NaN
# 3  374EC/3\nAP-119/ 2022-2023\nInstitute of Pharm...        NaN         NaN
# 4  374EC/4\nAP-120/ 2022-2023\nRaghavendra Instit...        NaN         NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0         NaN         NaN         NaN        NaN        NaN        NaN
# 1         NaN         NaN         NaN        NaN        NaN        NaN
# 2         NaN         NaN         NaN        NaN        NaN        NaN
# 3         NaN         NaN         NaN        NaN        NaN        NaN
# 4         NaN         NaN         NaN        NaN        NaN        NaN
#
#    Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# ...

# %%
# Dataframe name change
df['Institution_Name']=df['EC No. / Item No./ Institution Name /ID/ Course']

# %%
#Dataframe name change
df['Examining Authority']=df['Examining Authority / Hospital']

# %%
#creating a new data frame 
df2=df[['Institution_Name','Examining Authority', 'Decisions of 374 EC (22.8.2022)']]

# %%
#Reading  first five rows 
df2.head()
# Out:
#                                     Institution_Name  \
# 0  374EC/1\nAP-117/ 2022-2023\nAU College of Phar...
# 1  374EC/2\nAP-118/ 2022-2023\nGitam Institute of...
# 2    EC No. / Item No./ Institution Name /ID/ Course
# 3  374EC/3\nAP-119/ 2022-2023\nInstitute of Pharm...
# 4  374EC/4\nAP-120/ 2022-2023\nRaghavendra Instit...
#
#                                  Examining Authority  \
# 0  B.Pharm, Pharm.D, Pharm.D (PB) and M.Pharm The...
# 1  B.Pharm, M.Pharm The Registrar GITAM Universit...
# 2                     Examining Authority / Hospital
# 3  B.Pharm, M.Pharm\nThe Registrar Sri Padmavathi...
# 4  D.Pharm\nThe Secretary\nState Board of Technic...
#
#                      Decisions of 374 EC (22.8.2022)
# 0  B.Pharm\nB.Pharm course is already approved up...
# 1  B.Pharm\nB.Pharm course is already approved up...
# 2                    Decisions of 374 EC (22.8.2022)
# 3  B.Pharm\nB.Pharm course is already approved up...
# 4  D.Pharm\nD.Pharm course is already approved up...

# %%
# converting dataframe as string
df2=df2.applymap(str)
print(df2.dtypes)
# Out:
# Institution_Name                   object
# Examining Authority                object
# Decisions of 374 EC (22.8.2022)    object
# dtype: object

# %%
# find the string position 
df2.Institution_Name.str.find('PCI')
# Out:
# 0       98
# 1      152
# 2       -1
# 3      113
# 4      145
#       ...
# 171     -1
# 172      0
# 173     -1
# 174     -1
# 175     -1
# Name: Institution_Name, Length: 176, dtype: int64

# %%
df['PCI']=df.Institution_Name.str.split(' ')

# %%
df['PCI']
# Out:
# 0      [374EC/1\nAP-117/, 2022-2023\nAU, College, of,...
# 1      [374EC/2\nAP-118/, 2022-2023\nGitam, Institute...
# 2      [EC, No., /, Item, No./, Institution, Name, /I...
# 3      [374EC/3\nAP-119/, 2022-2023\nInstitute, of, P...
# 4      [374EC/4\nAP-120/, 2022-2023\nRaghavendra, Ins...
#                              ...
# 171                                                  NaN
# 172                                       [PCI, –, 2935]
# 173                                                  NaN
# 174                                                  NaN
# 175                                                  NaN
# Name: PCI, Length: 176, dtype: object

# %%
# conerting a new column from instute
df2['PCI'] = df2.Institution_Name.str.extract(r'\b(\w+)$', expand=True)
print(df2)
# Out:
#                                       Institution_Name  \
# 0    374EC/1\nAP-117/ 2022-2023\nAU College of Phar...
# 1    374EC/2\nAP-118/ 2022-2023\nGitam Institute of...
# 2      EC No. / Item No./ Institution Name /ID/ Course
# 3    374EC/3\nAP-119/ 2022-2023\nInstitute of Pharm...
# 4    374EC/4\nAP-120/ 2022-2023\nRaghavendra Instit...
# ..                                                 ...
# 171                                                nan
# 172                                         PCI – 2935
# 173                                                nan
# 174                                                nan
# 175                                                nan
#
#                                    Examining Authority  \
# 0    B.Pharm, Pharm.D, Pharm.D (PB) and M.Pharm The...
# 1    B.Pharm, M.Pharm The Registrar GITAM Universit...
# 2                       Examining Authority / Hospital
# 3    B.Pharm, M.Pharm\nThe Registrar Sri Padmavathi...
# ...

# %%
df2.head()
# Out:
#                                     Institution_Name  \
# 0  374EC/1\nAP-117/ 2022-2023\nAU College of Phar...
# 1  374EC/2\nAP-118/ 2022-2023\nGitam Institute of...
# 2    EC No. / Item No./ Institution Name /ID/ Course
# 3  374EC/3\nAP-119/ 2022-2023\nInstitute of Pharm...
# 4  374EC/4\nAP-120/ 2022-2023\nRaghavendra Instit...
#
#                                  Examining Authority  \
# 0  B.Pharm, Pharm.D, Pharm.D (PB) and M.Pharm The...
# 1  B.Pharm, M.Pharm The Registrar GITAM Universit...
# 2                     Examining Authority / Hospital
# 3  B.Pharm, M.Pharm\nThe Registrar Sri Padmavathi...
# 4  D.Pharm\nThe Secretary\nState Board of Technic...
#
#                      Decisions of 374 EC (22.8.2022)     PCI
# 0  B.Pharm\nB.Pharm course is already approved up...     151
# 1  B.Pharm\nB.Pharm course is already approved up...     687
# 2                    Decisions of 374 EC (22.8.2022)  Course
# 3  B.Pharm\nB.Pharm course is already approved up...     919
# ...

# %%
df2.tail()
# Out:
#     Institution_Name Examining Authority  \
# 171              nan                 nan
# 172       PCI – 2935                 nan
# 173              nan                 nan
# 174              nan                 nan
# 175              nan                 nan
#
#            Decisions of 374 EC (22.8.2022)   PCI
# 171    -Minimum Qualification for Teachers   nan
# 172  in Pharmacy Institutions Regulations,  2935
# 173                                   2014   nan
# 174   - Education Regulations, 1991 / 2020   nan
# 175     for the Diploma course in Pharmacy   nan

# %%
df2.head(10)
# Out:
#                                     Institution_Name  \
# 0  374EC/1\nAP-117/ 2022-2023\nAU College of Phar...
# 1  374EC/2\nAP-118/ 2022-2023\nGitam Institute of...
# 2    EC No. / Item No./ Institution Name /ID/ Course
# 3  374EC/3\nAP-119/ 2022-2023\nInstitute of Pharm...
# 4  374EC/4\nAP-120/ 2022-2023\nRaghavendra Instit...
# 5    EC No. / Item No./ Institution Name /ID/ Course
# 6  374EC/5\nAP-121/ 2022-2023\nGovt Polytechnic F...
# 7  374EC/6\nAP-122/ 2022-2023\nGovt Polytechnic F...
# 8  374EC/7\nAP-123/ 2022-2023\nGovt Polytechnic F...
# 9  374EC/8\nAP-124/ 2022-2023\nGovt Polytechnic F...
#
#                                  Examining Authority  \
# 0  B.Pharm, Pharm.D, Pharm.D (PB) and M.Pharm The...
# 1  B.Pharm, M.Pharm The Registrar GITAM Universit...
# 2                     Examining Authority / Hospital
# 3  B.Pharm, M.Pharm\nThe Registrar Sri Padmavathi...
# 4  D.Pharm\nThe Secretary\nState Board of Technic...
# 5                     Examining Authority / Hospital
# ...

# %%
df2.head(25)
# Out:
#                                      Institution_Name  \
# 0   374EC/1\nAP-117/ 2022-2023\nAU College of Phar...
# 1   374EC/2\nAP-118/ 2022-2023\nGitam Institute of...
# 2     EC No. / Item No./ Institution Name /ID/ Course
# 3   374EC/3\nAP-119/ 2022-2023\nInstitute of Pharm...
# 4   374EC/4\nAP-120/ 2022-2023\nRaghavendra Instit...
# 5     EC No. / Item No./ Institution Name /ID/ Course
# 6   374EC/5\nAP-121/ 2022-2023\nGovt Polytechnic F...
# 7   374EC/6\nAP-122/ 2022-2023\nGovt Polytechnic F...
# 8   374EC/7\nAP-123/ 2022-2023\nGovt Polytechnic F...
# 9   374EC/8\nAP-124/ 2022-2023\nGovt Polytechnic F...
# 10  374EC/9\nAP-125/ 2022-2023\nGovt Polytechnic F...
# 11  374EC/10\nAP-126/ 2022-2023\nGovt Polytechnic ...
# 12    EC No. / Item No./ Institution Name /ID/ Course
# 13  374EC/11\nAP-127/ 2022-2023\nSri Padmavathi Wo...
# 14  374EC/12\nAP-128/ 2022-2023\nSt Anns College O...
# 15  374EC/13\nRJ-133/ 2022-2023\nSchool Of Pharmac...
# ...

# %%
# Data cleaninng removing the rows which contains course in PCI column
df3=df2[df2['PCI'].str.contains('Course')==False]

# %%
# Reading the size of the dataframe
df3.shape
# Out:
# (139, 4)

# %%
# Reading first 25 rows of the dataframe
df3.head(25)
# Out:
#                                      Institution_Name  \
# 0   374EC/1\nAP-117/ 2022-2023\nAU College of Phar...
# 1   374EC/2\nAP-118/ 2022-2023\nGitam Institute of...
# 3   374EC/3\nAP-119/ 2022-2023\nInstitute of Pharm...
# 4   374EC/4\nAP-120/ 2022-2023\nRaghavendra Instit...
# 6   374EC/5\nAP-121/ 2022-2023\nGovt Polytechnic F...
# 7   374EC/6\nAP-122/ 2022-2023\nGovt Polytechnic F...
# 8   374EC/7\nAP-123/ 2022-2023\nGovt Polytechnic F...
# 9   374EC/8\nAP-124/ 2022-2023\nGovt Polytechnic F...
# 10  374EC/9\nAP-125/ 2022-2023\nGovt Polytechnic F...
# 11  374EC/10\nAP-126/ 2022-2023\nGovt Polytechnic ...
# 13  374EC/11\nAP-127/ 2022-2023\nSri Padmavathi Wo...
# 14  374EC/12\nAP-128/ 2022-2023\nSt Anns College O...
# 15  374EC/13\nRJ-133/ 2022-2023\nSchool Of Pharmac...
# 17  374EC/14\nRJ-134/ 2022-2023\nSchool of Pharmac...
# 18  374EC/15\nTS-123/ 2022-2023\nAnurag Group of I...
# 20  374EC/16\nTS-124/ 2022-2023\nSiddhartha Instit...
# ...

# %%
# organizing the dataframe
df4=df3[['PCI', 'Institution_Name', 'Examining Authority', 'Decisions of 374 EC (22.8.2022)']]

# %%
# renameing data frame
PCI_work=df4

# %%
PCI_work.head(20)
# Out:
#      PCI                                   Institution_Name  \
# 0    151  374EC/1\nAP-117/ 2022-2023\nAU College of Phar...
# 1    687  374EC/2\nAP-118/ 2022-2023\nGitam Institute of...
# 3    919  374EC/3\nAP-119/ 2022-2023\nInstitute of Pharm...
# 4   1684  374EC/4\nAP-120/ 2022-2023\nRaghavendra Instit...
# 6    741  374EC/5\nAP-121/ 2022-2023\nGovt Polytechnic F...
# 7    744  374EC/6\nAP-122/ 2022-2023\nGovt Polytechnic F...
# 8    745  374EC/7\nAP-123/ 2022-2023\nGovt Polytechnic F...
# 9    746  374EC/8\nAP-124/ 2022-2023\nGovt Polytechnic F...
# 10   748  374EC/9\nAP-125/ 2022-2023\nGovt Polytechnic F...
# 11   766  374EC/10\nAP-126/ 2022-2023\nGovt Polytechnic ...
# 13  2306  374EC/11\nAP-127/ 2022-2023\nSri Padmavathi Wo...
# 14  2371  374EC/12\nAP-128/ 2022-2023\nSt Anns College O...
# 15  3281  374EC/13\nRJ-133/ 2022-2023\nSchool Of Pharmac...
# 17  4371  374EC/14\nRJ-134/ 2022-2023\nSchool of Pharmac...
# 18   114  374EC/15\nTS-123/ 2022-2023\nAnurag Group of I...
# ...

# %%
PCI_work.tail()
# Out:
#       PCI Institution_Name Examining Authority  \
# 171   nan              nan                 nan
# 172  2935       PCI – 2935                 nan
# 173   nan              nan                 nan
# 174   nan              nan                 nan
# 175   nan              nan                 nan
#
#            Decisions of 374 EC (22.8.2022)
# 171    -Minimum Qualification for Teachers
# 172  in Pharmacy Institutions Regulations,
# 173                                   2014
# 174   - Education Regulations, 1991 / 2020
# 175     for the Diploma course in Pharmacy

# %%
# extracting PCI using string method
PCI_work = PCI_work.assign(PCI=PCI_work['Institution_Name'].str.extract('(PCI.*)'))

# %%
PCI_work.head()
# Out:
#           PCI                                   Institution_Name  \
# 0   PCI - 151  374EC/1\nAP-117/ 2022-2023\nAU College of Phar...
# 1   PCI – 687  374EC/2\nAP-118/ 2022-2023\nGitam Institute of...
# 3   PCI – 919  374EC/3\nAP-119/ 2022-2023\nInstitute of Pharm...
# 4  PCI - 1684  374EC/4\nAP-120/ 2022-2023\nRaghavendra Instit...
# 6   PCI – 741  374EC/5\nAP-121/ 2022-2023\nGovt Polytechnic F...
#
#                                  Examining Authority  \
# 0  B.Pharm, Pharm.D, Pharm.D (PB) and M.Pharm The...
# 1  B.Pharm, M.Pharm The Registrar GITAM Universit...
# 3  B.Pharm, M.Pharm\nThe Registrar Sri Padmavathi...
# 4  D.Pharm\nThe Secretary\nState Board of Technic...
# 6  D.Pharm\nThe Secretary\nState Board of Tech. E...
#
#                      Decisions of 374 EC (22.8.2022)
# 0  B.Pharm\nB.Pharm course is already approved up...
# 1  B.Pharm\nB.Pharm course is already approved up...
# 3  B.Pharm\nB.Pharm course is already approved up...
# ...

# %%
PCI_work.tail()
# Out:
#             PCI Institution_Name Examining Authority  \
# 171         NaN              nan                 nan
# 172  PCI – 2935       PCI – 2935                 nan
# 173         NaN              nan                 nan
# 174         NaN              nan                 nan
# 175         NaN              nan                 nan
#
#            Decisions of 374 EC (22.8.2022)
# 171    -Minimum Qualification for Teachers
# 172  in Pharmacy Institutions Regulations,
# 173                                   2014
# 174   - Education Regulations, 1991 / 2020
# 175     for the Diploma course in Pharmacy

# %%
PCI_work.head(10)
# Out:
#            PCI                                   Institution_Name  \
# 0    PCI - 151  374EC/1\nAP-117/ 2022-2023\nAU College of Phar...
# 1    PCI – 687  374EC/2\nAP-118/ 2022-2023\nGitam Institute of...
# 3    PCI – 919  374EC/3\nAP-119/ 2022-2023\nInstitute of Pharm...
# 4   PCI - 1684  374EC/4\nAP-120/ 2022-2023\nRaghavendra Instit...
# 6    PCI – 741  374EC/5\nAP-121/ 2022-2023\nGovt Polytechnic F...
# 7    PCI – 744  374EC/6\nAP-122/ 2022-2023\nGovt Polytechnic F...
# 8    PCI - 745  374EC/7\nAP-123/ 2022-2023\nGovt Polytechnic F...
# 9    PCI – 746  374EC/8\nAP-124/ 2022-2023\nGovt Polytechnic F...
# 10   PCI – 748  374EC/9\nAP-125/ 2022-2023\nGovt Polytechnic F...
# 11   PCI – 766  374EC/10\nAP-126/ 2022-2023\nGovt Polytechnic ...
#
#                                   Examining Authority  \
# 0   B.Pharm, Pharm.D, Pharm.D (PB) and M.Pharm The...
# 1   B.Pharm, M.Pharm The Registrar GITAM Universit...
# 3   B.Pharm, M.Pharm\nThe Registrar Sri Padmavathi...
# ...

# %%
PCI_work.head(100)
# Out:
#             PCI                                   Institution_Name  \
# 0     PCI - 151  374EC/1\nAP-117/ 2022-2023\nAU College of Phar...
# 1     PCI – 687  374EC/2\nAP-118/ 2022-2023\nGitam Institute of...
# 3     PCI – 919  374EC/3\nAP-119/ 2022-2023\nInstitute of Pharm...
# 4    PCI - 1684  374EC/4\nAP-120/ 2022-2023\nRaghavendra Instit...
# 6     PCI – 741  374EC/5\nAP-121/ 2022-2023\nGovt Polytechnic F...
# ..          ...                                                ...
# 119         NaN                           Meloor, THRISSUR, 680311
# 121         NaN                                                nan
# 122  PCI – 3785  374 EC/48\nAR-1 / 2022-2023\nARUNACHAL PRADESH...
# 124         NaN                                                nan
# 125    PCI-5241  374 EC/49\nJK-9 / 2022-2023\nJAMMU AND KASHMIR...
#
#                                    Examining Authority  \
# 0    B.Pharm, Pharm.D, Pharm.D (PB) and M.Pharm The...
# ...

# %%
df2_nan=df[df["PCI"] == 'NaN']

# %%
df2_nan.head(20)
# Out:
# Empty DataFrame
# Columns: [EC No. / Item No./ Institution Name /ID/ Course, Unnamed: 1, Unnamed: 2, Unnamed: 3, Unnamed: 4, Unnamed: 5, Unnamed: 6, Unnamed: 7, Unnamed: 8, Unnamed: 9, Unnamed: 10, Unnamed: 11, Unnamed: 12, Unnamed: 13, Examining Authority / Hospital, Unnamed: 15, Unnamed: 16, Decisions of 374 EC (22.8.2022), Instution_Name, Examining Authority, PCI, Institution_Name]
# Index: []
#
# [0 rows x 22 columns]

# %%
df3_nan=df[df["Examining Authority"] == 'NaN']

# %%
df3_nan
# Out:
# Empty DataFrame
# Columns: [EC No. / Item No./ Institution Name /ID/ Course, Unnamed: 1, Unnamed: 2, Unnamed: 3, Unnamed: 4, Unnamed: 5, Unnamed: 6, Unnamed: 7, Unnamed: 8, Unnamed: 9, Unnamed: 10, Unnamed: 11, Unnamed: 12, Unnamed: 13, Examining Authority / Hospital, Unnamed: 15, Unnamed: 16, Decisions of 374 EC (22.8.2022), Instution_Name, Examining Authority, PCI, Institution_Name]
# Index: []
#
# [0 rows x 22 columns]

# %%
df4_nan=df[df["Decisions of 374 EC (22.8.2022)"] == 'NaN']

# %%
df4_nan.head()
# Out:
# Empty DataFrame
# Columns: [EC No. / Item No./ Institution Name /ID/ Course, Unnamed: 1, Unnamed: 2, Unnamed: 3, Unnamed: 4, Unnamed: 5, Unnamed: 6, Unnamed: 7, Unnamed: 8, Unnamed: 9, Unnamed: 10, Unnamed: 11, Unnamed: 12, Unnamed: 13, Examining Authority / Hospital, Unnamed: 15, Unnamed: 16, Decisions of 374 EC (22.8.2022), Instution_Name, Examining Authority, PCI, Institution_Name]
# Index: []
#
# [0 rows x 22 columns]

# %%
PCI_work[PCI_work["Institution_Name"].str.contains("PCI")]
# Out:
#             PCI                                   Institution_Name  \
# 0     PCI - 151  374EC/1\nAP-117/ 2022-2023\nAU College of Phar...
# 1     PCI – 687  374EC/2\nAP-118/ 2022-2023\nGitam Institute of...
# 3     PCI – 919  374EC/3\nAP-119/ 2022-2023\nInstitute of Pharm...
# 4    PCI - 1684  374EC/4\nAP-120/ 2022-2023\nRaghavendra Instit...
# 6     PCI – 741  374EC/5\nAP-121/ 2022-2023\nGovt Polytechnic F...
# ..          ...                                                ...
# 157  PCI – 3242  374EC/57\nMP-189/ 2022-2023\nMADHYA PRADESH\nG...
# 158  PCI – 1184  374EC/58\nPB- 109/2022-2023\nPUNJAB\nLala Lajp...
# 159  PCI – 1185  374EC/59\nPB-110/ 2022-2023\nPUNJAB\nLala Lajp...
# 161  PCI - 1743  374EC/60\nPB-111/ 2022-2023\nPUNJAB\nRayat Ins...
# 172  PCI – 2935                                         PCI – 2935
#
#                                    Examining Authority  \
# 0    B.Pharm, Pharm.D, Pharm.D (PB) and M.Pharm The...
# ...

# %%
PCI_work.head(1000)
# Out:
#             PCI                                   Institution_Name  \
# 0     PCI - 151  374EC/1\nAP-117/ 2022-2023\nAU College of Phar...
# 1     PCI – 687  374EC/2\nAP-118/ 2022-2023\nGitam Institute of...
# 3     PCI – 919  374EC/3\nAP-119/ 2022-2023\nInstitute of Pharm...
# 4    PCI - 1684  374EC/4\nAP-120/ 2022-2023\nRaghavendra Instit...
# 6     PCI – 741  374EC/5\nAP-121/ 2022-2023\nGovt Polytechnic F...
# ..          ...                                                ...
# 171         NaN                                                nan
# 172  PCI – 2935                                         PCI – 2935
# 173         NaN                                                nan
# 174         NaN                                                nan
# 175         NaN                                                nan
#
#                                    Examining Authority  \
# 0    B.Pharm, Pharm.D, Pharm.D (PB) and M.Pharm The...
# ...

# %%
# To find the D.Pharm course Alloated colleges
PCI_work[PCI_work["Decisions of 374 EC (22.8.2022)"].str.contains("D.Pharm course")]
# Out:
#             PCI                                   Institution_Name  \
# 4    PCI - 1684  374EC/4\nAP-120/ 2022-2023\nRaghavendra Instit...
# 6     PCI – 741  374EC/5\nAP-121/ 2022-2023\nGovt Polytechnic F...
# 7     PCI – 744  374EC/6\nAP-122/ 2022-2023\nGovt Polytechnic F...
# 8     PCI - 745  374EC/7\nAP-123/ 2022-2023\nGovt Polytechnic F...
# 9     PCI – 746  374EC/8\nAP-124/ 2022-2023\nGovt Polytechnic F...
# 10    PCI – 748  374EC/9\nAP-125/ 2022-2023\nGovt Polytechnic F...
# 11    PCI – 766  374EC/10\nAP-126/ 2022-2023\nGovt Polytechnic ...
# 13   PCI – 2306  374EC/11\nAP-127/ 2022-2023\nSri Padmavathi Wo...
# 15   PCI - 3281  374EC/13\nRJ-133/ 2022-2023\nSchool Of Pharmac...
# 17   PCI – 4371  374EC/14\nRJ-134/ 2022-2023\nSchool of Pharmac...
# 20   PCI – 2196  374EC/16\nTS-124/ 2022-2023\nSiddhartha Instit...
# 21     PCI-2277  374EC/17\nTS-125/ 2022-2023\nSri Balaji Colleg...
# 23   PCI - 2552  374EC/18\nTS-126/ 2022-2023\nVaagdevi College ...
# ...

# %%
PCI_work[PCI_work["Decisions of 374 EC (22.8.2022)"].str.contains("M.Pharm course")]
# Out:
#            PCI                                   Institution_Name  \
# 97  PCI – 1632  374 EC/39\nTN-102 / 2022-2023\nTAMIL NADU\nPsv...
#
#                                   Examining Authority  \
# 97  D.Pharm\nThe Director Directorate of Medical E...
#
#                       Decisions of 374 EC (22.8.2022)
# 97  D.Pharm\nExtend approval up to 2022-2023 acade...
