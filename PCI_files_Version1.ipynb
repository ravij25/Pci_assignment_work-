# %%
import pandas as pd

# %%
# !pip install xlrd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
df= pd.read_excel(r"E:\AI\Mongodb\374EC.xlsx")

# %%
# Out:
#      EC No. / Item No./ Institution Name /ID/ Course Unnamed: 1  Unnamed: 2  \
# 0  374EC/1\nAP-117/ 2022-2023\nAU College of Phar...        NaN         NaN
# 1  374EC/2\nAP-118/ 2022-2023\nGitam Institute of...        NaN         NaN
# 2    EC No. / Item No./ Institution Name /ID/ Course        NaN         NaN
# 3  374EC/3\nAP-119/ 2022-2023\nInstitute of Pharm...        NaN         NaN
# 4  374EC/4\nAP-120/ 2022-2023\nRaghavendra Instit...        NaN         NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0         NaN         NaN         NaN        NaN        NaN        NaN
# 1         NaN         NaN         NaN        NaN        NaN        NaN
# 2         NaN         NaN         NaN        NaN        NaN        NaN
# 3         NaN         NaN         NaN        NaN        NaN        NaN
# 4         NaN         NaN         NaN        NaN        NaN        NaN
#
#    Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# ...

# %%
df2=df[['EC No. / Item No./ Institution Name /ID/ Course', 'Examining Authority / Hospital', 'Decisions of 374 EC (22.8.2022)']]

# %%
df2.head()
# Out:
#      EC No. / Item No./ Institution Name /ID/ Course  \
# 0  374EC/1\nAP-117/ 2022-2023\nAU College of Phar...
# 1  374EC/2\nAP-118/ 2022-2023\nGitam Institute of...
# 2    EC No. / Item No./ Institution Name /ID/ Course
# 3  374EC/3\nAP-119/ 2022-2023\nInstitute of Pharm...
# 4  374EC/4\nAP-120/ 2022-2023\nRaghavendra Instit...
#
#                       Examining Authority / Hospital  \
# 0  B.Pharm, Pharm.D, Pharm.D (PB) and M.Pharm The...
# 1  B.Pharm, M.Pharm The Registrar GITAM Universit...
# 2                     Examining Authority / Hospital
# 3  B.Pharm, M.Pharm\nThe Registrar Sri Padmavathi...
# 4  D.Pharm\nThe Secretary\nState Board of Technic...
#
#                      Decisions of 374 EC (22.8.2022)
# 0  B.Pharm\nB.Pharm course is already approved up...
# 1  B.Pharm\nB.Pharm course is already approved up...
# 2                    Decisions of 374 EC (22.8.2022)
# 3  B.Pharm\nB.Pharm course is already approved up...
# 4  D.Pharm\nD.Pharm course is already approved up...

# %%
df2.describe()
# Out:
#         EC No. / Item No./ Institution Name /ID/ Course  \
# count                                               126
# unique                                               95
# top     EC No. / Item No./ Institution Name /ID/ Course
# freq                                                 31
#
#         Examining Authority / Hospital  Decisions of 374 EC (22.8.2022)
# count                              100                              156
# unique                              63                              109
# top     Examining Authority / Hospital  Decisions of 374 EC (22.8.2022)
# freq                                31                               31

# %%
df2.isna().sum()
# Out:
# EC No. / Item No./ Institution Name /ID/ Course    50
# Examining Authority / Hospital                     76
# Decisions of 374 EC (22.8.2022)                    20
# dtype: int64

# %%
df2=df2.applymap(str)
print(df2.dtypes)
# Out:
# EC No. / Item No./ Institution Name /ID/ Course    object
# Examining Authority / Hospital                     object
# Decisions of 374 EC (22.8.2022)                    object
# dtype: object

# %%
x = df2['EC No. / Item No./ Institution Name /ID/ Course'].find("PCI")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [83], in <cell line: 1>()
# ----> 1 x = df2['EC No. / Item No./ Institution Name /ID/ Course'].find("PCI")
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'find'

# %%
df2['PCI'] = df2['EC No. / Item No./ Institution Name /ID/ Course'].str[x:10]
df2['PCI']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 171   NaN
# 172   NaN
# 173   NaN
# 174   NaN
# 175   NaN
# Name: PCI, Length: 176, dtype: float64

# %%
df2
# Out:
#        EC No. / Item No./ Institution Name /ID/ Course  \
# 0    374EC/1\nAP-117/ 2022-2023\nAU College of Phar...
# 1    374EC/2\nAP-118/ 2022-2023\nGitam Institute of...
# 2      EC No. / Item No./ Institution Name /ID/ Course
# 3    374EC/3\nAP-119/ 2022-2023\nInstitute of Pharm...
# 4    374EC/4\nAP-120/ 2022-2023\nRaghavendra Instit...
# ..                                                 ...
# 171                                                nan
# 172                                         PCI – 2935
# 173                                                nan
# 174                                                nan
# 175                                                nan
#
#                         Examining Authority / Hospital  \
# 0    B.Pharm, Pharm.D, Pharm.D (PB) and M.Pharm The...
# 1    B.Pharm, M.Pharm The Registrar GITAM Universit...
# 2                       Examining Authority / Hospital
# 3    B.Pharm, M.Pharm\nThe Registrar Sri Padmavathi...
# ...

# %%
df2['Instution_Name']=df2['EC No. / Item No./ Institution Name /ID/ Course']

# %%
df2.head()
# Out:
#      EC No. / Item No./ Institution Name /ID/ Course  \
# 0  374EC/1\nAP-117/ 2022-2023\nAU College of Phar...
# 1  374EC/2\nAP-118/ 2022-2023\nGitam Institute of...
# 2    EC No. / Item No./ Institution Name /ID/ Course
# 3  374EC/3\nAP-119/ 2022-2023\nInstitute of Pharm...
# 4  374EC/4\nAP-120/ 2022-2023\nRaghavendra Instit...
#
#                       Examining Authority / Hospital  \
# 0  B.Pharm, Pharm.D, Pharm.D (PB) and M.Pharm The...
# 1  B.Pharm, M.Pharm The Registrar GITAM Universit...
# 2                     Examining Authority / Hospital
# 3  B.Pharm, M.Pharm\nThe Registrar Sri Padmavathi...
# 4  D.Pharm\nThe Secretary\nState Board of Technic...
#
#                      Decisions of 374 EC (22.8.2022)  Ec No.  \
# 0  B.Pharm\nB.Pharm course is already approved up...     NaN
# 1  B.Pharm\nB.Pharm course is already approved up...     NaN
# 2                    Decisions of 374 EC (22.8.2022)     NaN
# 3  B.Pharm\nB.Pharm course is already approved up...     NaN
# ...

# %%
x= df2.Instution_Name.str.find('PCI')

# %%
# Out:
#        EC No. / Item No./ Institution Name /ID/ Course  \
# 0    374EC/1\nAP-117/ 2022-2023\nAU College of Phar...
# 1    374EC/2\nAP-118/ 2022-2023\nGitam Institute of...
# 2      EC No. / Item No./ Institution Name /ID/ Course
# 3    374EC/3\nAP-119/ 2022-2023\nInstitute of Pharm...
# 4    374EC/4\nAP-120/ 2022-2023\nRaghavendra Instit...
# ..                                                 ...
# 171                                                nan
# 172                                         PCI – 2935
# 173                                                nan
# 174                                                nan
# 175                                                nan
#
#                         Examining Authority / Hospital  \
# 0    B.Pharm, Pharm.D, Pharm.D (PB) and M.Pharm The...
# 1    B.Pharm, M.Pharm The Registrar GITAM Universit...
# 2                       Examining Authority / Hospital
# 3    B.Pharm, M.Pharm\nThe Registrar Sri Padmavathi...
# ...

# %%
df3=df2[['Instution_Name','Examining Authority / Hospital', 'Decisions of 374 EC (22.8.2022)']]

# %%
df3.head()
# Out:
#                                       Instution_Name  \
# 0  374EC/1\nAP-117/ 2022-2023\nAU College of Phar...
# 1  374EC/2\nAP-118/ 2022-2023\nGitam Institute of...
# 2    EC No. / Item No./ Institution Name /ID/ Course
# 3  374EC/3\nAP-119/ 2022-2023\nInstitute of Pharm...
# 4  374EC/4\nAP-120/ 2022-2023\nRaghavendra Instit...
#
#                       Examining Authority / Hospital  \
# 0  B.Pharm, Pharm.D, Pharm.D (PB) and M.Pharm The...
# 1  B.Pharm, M.Pharm The Registrar GITAM Universit...
# 2                     Examining Authority / Hospital
# 3  B.Pharm, M.Pharm\nThe Registrar Sri Padmavathi...
# 4  D.Pharm\nThe Secretary\nState Board of Technic...
#
#                      Decisions of 374 EC (22.8.2022)
# 0  B.Pharm\nB.Pharm course is already approved up...
# 1  B.Pharm\nB.Pharm course is already approved up...
# 2                    Decisions of 374 EC (22.8.2022)
# 3  B.Pharm\nB.Pharm course is already approved up...
# 4  D.Pharm\nD.Pharm course is already approved up...

# %%
df
# Out:
# 0      374EC/1\nAP-117/ 2022-2023\nAU College of Phar...
# 1      374EC/2\nAP-118/ 2022-2023\nGitam Institute of...
# 2        EC No. / Item No./ Institution Name /ID/ Course
# 3      374EC/3\nAP-119/ 2022-2023\nInstitute of Pharm...
# 4      374EC/4\nAP-120/ 2022-2023\nRaghavendra Instit...
#                              ...
# 171                                                  nan
# 172                                           PCI – 2935
# 173                                                  nan
# 174                                                  nan
# 175                                                  nan
# Name: Instution_Name, Length: 176, dtype: object

# %%
df2['PCI'] = df2['EC No. / Item No./ Institution Name /ID/ Course'].str[x:10]

# %%
df2['PCI']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 171   NaN
# 172   NaN
# 173   NaN
# 174   NaN
# 175   NaN
# Name: PCI, Length: 176, dtype: float64
